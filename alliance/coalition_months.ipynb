# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('./coalition_months_NDA1', 'rb') as f:
    coalition_months_NDA1 = pickle.load(f)

# %%
with open('./coalition_months_NDA2', 'rb') as f:
    coalition_months_NDA2 = pickle.load(f)

# %%
with open('./coalition_months_UPA', 'rb') as f:
    coalition_months_UPA = pickle.load(f)

# %%
coalition_months_UPA.shape, coalition_months_NDA1.shape, coalition_months_NDA2.shape
# Out:
# ((31, 3), (32, 3), (31, 3))

# %%
coalition_months_UPA
# Out:
#                    NDA  UPA  ThirdFront
# andhra pradesh       0   58           0
# arunachal pradesh    0   60           0
# assam                0   60           0
# bihar               60    0           0
# chhattisgarh        60    0           0
# goa                 26   34           0
# gujarat             60    0           0
# haryana              0   55           0
# himachal pradesh    43   16           0
# jammu & kashmir      0    0          60
# jharkhand           28    0          10
# karnataka           48   12           0
# kerala               0   36          24
# lakshadweep          0   36          24
# madhya pradesh      60    0           0
# maharashtra          0   60           0
# manipur              0   60           0
# meghalaya            0   60           0
# mizoram              0   60           0
# nagaland             0    0          60
# nct of delhi         0   56           4
# odisha               0    0          60
# ...

# %%
coalition_months_NDA1
# Out:
# array([['andhra pradesh', '0', '0', '60'],
#        ['arunachal pradesh', '29', '28', '3'],
#        ['assam', '36', '24', '0'],
#        ['bihar', '57', '0', '0'],
#        ['chhattisgarh', '55', '0', '0'],
#        ['goa', '55', '0', '0'],
#        ['gujarat', '61', '0', '0'],
#        ['haryana', '55', '0', '0'],
#        ['himachal pradesh', '17', '43', '0'],
#        ['jammu & kashmir', '0', '0', '36'],
#        ['jharkhand', '53', '0', '0'],
#        ['karnataka', '0', '48', '12'],
#        ['kerala', '0', '24', '36'],
#        ['lakshadweep', '0', '24', '36'],
#        ['madhya pradesh', '61', '0', '0'],
#        ['maharashtra', '53', '0', '0'],
#        ['manipur', '26', '33', '0'],
#        ['meghalaya', '12', '48', '0'],
#        ['mizoram', '0', '55', '5'],
#        ['nagaland', '0', '0', '60'],
#        ['nct of delhi', '0', '0', '61'],
#        ['odisha', '0', '0', '61'],
#        ['puducherry', '24', '36', '0'],
#        ['punjab', '34', '26', '0'],
# ...

# %%
coalition_months_NDA2
# Out:
# array([['andhra pradesh', '0', '0', '24'],
#        ['arunachal pradesh', '24', '0', '0'],
#        ['assam', '24', '0', '0'],
#        ['bihar', '24', '0', '0'],
#        ['chhattisgarh', '0', '24', '0'],
#        ['goa', '24', '0', '0'],
#        ['gujarat', '24', '0', '0'],
#        ['haryana', '19', '0', '0'],
#        ['himachal pradesh', '24', '0', '0'],
#        ['jharkhand', '7', '17', '0'],
#        ['karnataka', '0', '24', '0'],
#        ['kerala', '0', '0', '24'],
#        ['lakshadweep', '0', '0', '24'],
#        ['madhya pradesh', '24', '0', '0'],
#        ['maharashtra', '17', '0', '0'],
#        ['manipur', '24', '0', '0'],
#        ['meghalaya', '0', '0', '24'],
#        ['mizoram', '0', '0', '24'],
#        ['nagaland', '24', '0', '0'],
#        ['nct of delhi', '0', '0', '24'],
#        ['odisha', '0', '0', '24'],
#        ['puducherry', '0', '23', '0'],
#        ['punjab', '0', '24', '0'],
#        ['rajasthan', '0', '24', '0'],
# ...
